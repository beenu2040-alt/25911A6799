# %%
from math import *
import numpy as np
import matplotlib.pyplot as plt  
def f(x):
    return eval(function)
function= input("enter the function")
a=float(input("enter lower limit"))
b=float(input("enter higher limit"))
tolerance=float(input("enter tolerance"))
if f(a)*f(b)>0:
    print("invalid interval")
else:
    while abs(b-a)>tolerance:
        c=(a+b)/2
        if abs(f(c))<tolerance:
            break
        elif f(a)*f(c)<0:
            b=c
        else:
            a=c
    print("approx root=",round(c,4))
    plt.axhline(0,color='black')
    plt.axvline(0,color='black')
    plt.grid(True)
    plt.ylabel("f(x)")
    plt.xlabel("x")
    plt.title("bisection method")
    x=np.linspace(c-5,c+5,400)
    y=[f(i) for i in x]
    plt.plot(x,y,label="f(x)")
    plt.scatter(c,f(c),color='red',s=60,label="approx root")
    plt.legend()
    plt.show()
# Out:
# approx root= 2.7065
